# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
print("Hello")

print("Vscode")
# Out:
# StatementMeta(, 399afa78-1ee3-442f-adcc-c6bd71b7fdcc, 3, Finished, Available, Finished)
# Hello
# Vscode

# %%
print("this was edited in VScode")
# Out:
# this was edited in VScode
