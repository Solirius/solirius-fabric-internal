# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
print("other extension")
# Out:
# StatementMeta(, 56ea2c79-ea66-407d-9d4f-3ad84aebe8bf, 3, Finished, Available, Finished, False)
# other extension

# %%
print("new code")
# Out:
# new code

# %%
print("some other code")
# Out:
# some other code

# %%
print("is this coming up")
# Out:
# is this coming up
